# %%
# !pip install BeautifulSoup4
# Out:
# Collecting BeautifulSoup4
#   Downloading beautifulsoup4-4.9.1-py3-none-any.whl (115 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.0.1-py3-none-any.whl (32 kB)
# Installing collected packages: soupsieve, BeautifulSoup4
# Successfully installed BeautifulSoup4-4.9.1 soupsieve-2.0.1

# %%
def input_your_keyword(input_value):
    import requests
    temp = input("정렬 기준을 선택하세요\n1.최신 순\n2.조회수 순\n3.검색어관련성 : ")
    print("\n\n\n\n\n")
    if temp == '1':
        order = 'date'
    elif temp == '2':
        order = 'viewCount'
    else :
        order = 'relevance'
    temp = []
    params = {
        'part': 'snippet',
        'key' : 'AIzaSyCi5ManLXIOKIgl6JBJzJUwUDy4_1oQZyg',
         'maxResults': 15,
        'chart': 'mostPopular',
        'q': input_value,
        'relatedToVideoId' : None,
        'type' : 'video',
        'order' : order
    }
    comments_params = {
    'key' : 'AIzaSyCi5ManLXIOKIgl6JBJzJUwUDy4_1oQZyg',
    'part': ['snippet', 'id'],
    'order': 'relevance',

    'videoId' : ''
}
    
    resp = requests.get("https://www.googleapis.com/youtube/v3/search", params=params)
    
    comments_url = 'https://www.googleapis.com/youtube/v3/commentThreads'
    result_list = resp.json()['items']
    for i in result_list:
        VID = i['id']['videoId']
        tit = i['snippet']['title']
        desc = i['snippet']['description']
        ch_tit = i['snippet']['channelTitle']
        split_T = i['snippet']['publishedAt'].split('T')
        date_list = split_T[0].split('-')
        time_list = split_T[1].split(':')
        time_date = date_list[0]+"년 "+date_list[1]+"월 "+date_list[2]+"일 "+time_list[0]+"시 "+time_list[1]+"분 "+time_list[2][0:2]+"초" 
        comments_list = []
        comments_params['videoId'] = VID
        comments_resp = requests.get(comments_url,params = comments_params)
        # from pprint import pprint
        data_ = comments_resp.json()
        for j in range(5):
            try:
                name = data_['items'][j]['snippet']['topLevelComment']['snippet']['authorDisplayName']
                contents = data_['items'][j]['snippet']['topLevelComment']['snippet']['textDisplay']
                comments_list.append([
                    name,contents
                    ])
            except:
                print('댓글 없음')
                from pprint import pprint
                pprint(data_)
                print('-'*30)
                comments_list.append(
                    [
                        None, None
                    ]
                )
        temp.append([ch_tit,tit,desc,VID,time_date,comments_list])
        
    for index,i in enumerate(temp):
        print("{}번째 영상".format(index+1))
        print("채널명 : ",i[0],"\n업로드 날짜 : ",i[4],"\n제목 :", i[1],"\n설명 : ",i[2],"\nURL : https://www.youtube.com/watch?v={}".format(i[3]))
        print("\n","-"*20,"{}번째 영상 댓글".format(index+1),"-"*20,"\n")
        for j in i[-1]:
            print(j[0]," : ",j[1],'\n',)
        print("\n","-"*40,"\n\n\n")

# %%
input_your_keyword('페이커')
# Out:
# 정렬 기준을 선택하세요
# 1.최신 순
# 2.조회수 순
# 3.검색어관련성 : 3
#
#
#
#
#
#
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 댓글 없음
# {'error': {'code': 403,
#            'errors': [{'domain': 'global',
#                        'message': 'The request is missing a valid API key.',
#                        'reason': 'forbidden'}],
#            'message': 'The request is missing a valid API key.',
#            'status': 'PERMISSION_DENIED'}}
# ------------------------------
# 1번째 영상
# 채널명 :  LoL PD
# 업로드 날짜 :  2020년 08월 15일 03시 00분 13초
# 제목 : 지리는 펜타킬! 페이커 8월 롤 매드무비 #2 [T1 Faker Montage]
# 설명 :  매일 낮 12시 업로드 롤 매드무비 채널 롤피디 구독과 좋아요 알림 설정은 저에게 매우 큰 힘이 됩니다! 영상에 문제가 있다면 언제든 메일 주세요. 최대한 빨리 해결 ...
# URL : https://www.youtube.com/watch?v=hvHLbLA8iu0
#
#  -------------------- 1번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 2번째 영상
# 채널명 :  T1 Faker
# 업로드 날짜 :  2020년 08월 12일 11시 18분 31초
# 제목 : 페이커의 화난 미드 루시안 [FULL GAME] [Faker Stream Highlight]
# 설명 :  여러분 미드 루시안 진짜 좋아요. 솔랭에서 꼭 픽해보세요. #T1 #Faker #Lucian * Faker Twitch: twitch.tv/faker Welcome to T1 'Faker' Official Youtube Channel !
# URL : https://www.youtube.com/watch?v=-twx7ibsK2g
#
#  -------------------- 2번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 3번째 영상
# 채널명 :  롤센세
# 업로드 날짜 :  2020년 08월 14일 02시 00분 01초
# 제목 : 신챔 요네 페이커도 써봣다! 페이커 8월 매드무비 // T1 Faker
# 설명 :  롤 #LOL #리그오브레전드 #페이커 #Faker - 페이커 매드무비 입니다! - 구독은 저에게 힘! - https://hoy.kr/qEgK (감사감사) BGM 1. Culture Code - Fairytale (feat.
# URL : https://www.youtube.com/watch?v=GpK74WAtzuw
#
#  -------------------- 3번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 4번째 영상
# 채널명 :  T1 Faker
# 업로드 날짜 :  2020년 08월 05일 10시 35분 18초
# 제목 : 페이커의 아리 키우기를 풀 게임으로! [Faker Stream Highlight] [Full Game]
# 설명 :  화제의 그 게임! 페이커 선수의 아리 플레이를 풀버전으로 준비했습니다. 여러분 아리는 강합니다. #Faker #Ahri * Faker Twitch: twitch.tv/faker Welcome to T1 'Faker' ...
# URL : https://www.youtube.com/watch?v=sjlafnqdmYU
#
#  -------------------- 4번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 5번째 영상
# 채널명 :  관전너굴
# 업로드 날짜 :  2020년 08월 13일 03시 00분 07초
# 제목 : 기대되는 피지컬 페이커 8월 롤 매드무비 / T1 Faker Montage
# 설명 :  페이커 롤 매드무비 T1 Faker Montage 구독과 좋아요 부탁드립니다~!! -BGM- Track: 3rd Prototype - Renegade (feat. Harley Bird & Valentina Franco) [NCS ...
# URL : https://www.youtube.com/watch?v=KZpynE6opMA
#
#  -------------------- 5번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 6번째 영상
# 채널명 :  나는상윤
# 업로드 날짜 :  2020년 08월 14일 05시 00분 05초
# 제목 : [정복자 이즈리얼] 페이커, 칸, 타잔, 호잇 미친 초강력 상체 만나서 버스 타는 강의
# 설명 :  버스강의 #강팀의조건 #씨맥어록 더 많은 영상 보러가기▷https://bit.ly/30IxDtx 방송 문의 제안▷ kwonsy95@naver.com 광고제작 ▷ voidstudio8@gmail.com ※ 좋 ...
# URL : https://www.youtube.com/watch?v=Z7K6nCPJpOY
#
#  -------------------- 6번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 7번째 영상
# 채널명 :  T1 Faker
# 업로드 날짜 :  2020년 08월 09일 10시 58분 50초
# 제목 : 테디, 피넛 진실의 방으로 드루와! [Faker Stream Highlight]
# 설명 :  오랜만에 모데카이저를 꺼낸 페이커. 진실의 방으로 친구들을 소환하는데... #Faker #T1 #Mordekaiser * Faker Twitch: twitch.tv/faker Welcome to T1 'Faker' Official ...
# URL : https://www.youtube.com/watch?v=ZTtkFieEOIc
#
#  -------------------- 7번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 8번째 영상
# 채널명 :  T1 Faker
# 업로드 날짜 :  2020년 07월 30일 08시 44분 05초
# 제목 : 페이커, 이상한 나라의 갈리오 [Faker Stream Highlight]
# 설명 :  페이커의 갈리오 타임! 이상한 이상혁님의 갈리오를 만나보세요! #Faker #Galio * Faker Twitch: twitch.tv/faker Welcome to T1 'Faker' Official Youtube Channel !
# URL : https://www.youtube.com/watch?v=-DTIFfvbMDM
#
#  -------------------- 8번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 9번째 영상
# 채널명 :  티모와
# 업로드 날짜 :  2020년 08월 09일 01시 00분 11초
# 제목 : 폐관수련한 페이커의 피지컬 매드무비 / T1 Faker Montage
# 설명 :  매일 매일 올라오는 극 천상계 프로게이머/아마추어 매드무비 ▷ 구독과 좋아요 누르시면 가장 빠르게 시청 가능 ▷ BGM - NEFFEX - Careless [Copyright Free] ...
# URL : https://www.youtube.com/watch?v=rqbL5nPhZ7I
#
#  -------------------- 9번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 10번째 영상
# 채널명 :  백크 Baekk
# 업로드 날짜 :  2020년 08월 04일 03시 40분 57초
# 제목 : 페이커 뺨치는 반응속도
# 설명 :  재밌게 시청해주세요! 모든 문의사항은 bkh173999@gmail.com.
# URL : https://www.youtube.com/watch?v=rXjJqq1AuvQ
#
#  -------------------- 10번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 11번째 영상
# 채널명 :  저라뎃 JUSTLIKETHAT
# 업로드 날짜 :  2020년 08월 01일 12시 30분 03초
# 제목 : 페이커 분노의 조이픽.. 말도 안되는 페이커식 킬각ㄷㄷ
# 설명 :  읽어주세요─▽──────────────── 챌린저 정글러 저라뎃의 저튜브에 오신 것을 환영합니다! 구독과 알람설정, 좋아요를 꼭 눌러주세요^^ ...
# URL : https://www.youtube.com/watch?v=XUDXEDa-KMQ
#
#  -------------------- 11번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 12번째 영상
# 채널명 :  LoL PD
# 업로드 날짜 :  2020년 08월 04일 03시 00분 09초
# 제목 : 각성한 피지컬! 페이커 7-8월 롤 매드무비 [T1 Faker Montage]
# 설명 :  천상계 영상 신청방법 → https://bit.ly/2Tn5PtV 구독과 좋아요 알림 설정은 저에게 매우 큰 힘이 됩니다! ↓ 하단 더보기를 누르시면 BGM 정보 및 채널 설명이 ...
# URL : https://www.youtube.com/watch?v=SEPY5wPtH6g
#
#  -------------------- 12번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 13번째 영상
# 채널명 :  가붕이
# 업로드 날짜 :  2020년 08월 11일 23시 00분 04초
# 제목 : 페이커 탑 정글이 터져도 무조건 이긴다! 페칼리 구마유시 T1 2명이 하드캐리 중? Faker &amp; Gumayusi
# 설명 :  페이커 아칼리 구마유시 케이틀린 도란 제이스 켈린 카르마 vs 상윤 진 비스타 세나 이안 볼리베어 온플릭 세트 (8월 12일) 매일 업로드되는 영상을 놓치지 않기 위해 ...
# URL : https://www.youtube.com/watch?v=DR-QFY3hEmU
#
#  -------------------- 13번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 14번째 영상
# 채널명 :  T1 Faker
# 업로드 날짜 :  2020년 07월 21일 04시 02분 29초
# 제목 : 잡았죠? 페이커가 제드 해봤습니다. [Faker Stream Highlight]
# 설명 :  간만에 돌아온 페이커 선수의 제드! 이상혁 선수의 제드는 괴연 LCK에 등장할까요? #Faker #Zed * Faker Twitch: twitch.tv/faker Welcome to T1 'Faker' Official ...
# URL : https://www.youtube.com/watch?v=_0XrH_aWj-o
#
#  -------------------- 14번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
#
#
#
# 15번째 영상
# 채널명 :  인강월드
# 업로드 날짜 :  2020년 08월 14일 13시 50분 16초
# 제목 : [ENG] T1 페이커 조이 분석 영상, T1 Faker joe analysis
# 설명 :  페이커조이 #조이 #joe #조이강의 #페이커 Track: Diviners X Riell - Slow [NCS Release] Music provided by NoCopyrightSounds. Watch: ...
# URL : https://www.youtube.com/watch?v=4P1eaw3sNxI
#
#  -------------------- 15번째 영상 댓글 --------------------
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
# None  :  None
#
#
#  ----------------------------------------
