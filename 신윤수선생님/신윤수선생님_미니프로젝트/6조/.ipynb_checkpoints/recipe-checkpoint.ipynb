# %%
import requests 
from bs4 import BeautifulSoup
import re
import pandas as pd
import time as timetime
from selenium import webdriver
import urllib
from tqdm.notebook import tqdm_notebook

# %%
## 청정원레시피
def get_recipe1(have_list) :
    recipe = []
    url_list=[]
    
    ## 사이트안에서 가진 재료를 입력했을때의 레시피 리스트 접속
    for i, val in enumerate(have_list) :
        if i == 0 :
            url_list.append(val)
        else :
            a = "+"
            b = a + val
            url_list.append(b)
    url_str = ''.join(url_list)
    resp = requests.request("GET", "http://www.chungjungone.com/knowhow/recipe/recipeListNew.do?s_str={}&recp_kind_cd=&recp_kind_cd_nm=&recp_situ_cd=&recp_situ_cd_nm=&x=0&y=0".format(url_str)) 
    soup = BeautifulSoup(resp.text)
    find_ul = soup.find('ul', class_ = 'recipe_ul fourList')
    
    ## 관련 레시피리스트가 없을 경우
    if find_ul is None :
        recipe.append({
                'title' : "",
                'url' : "",
                'time' : "",
                'level' : "",
                'ingredient' : ""
            })
        return recipe
    else :
        find_li = find_ul.find_all('li')

    ## url 가져오기
    recipe_url = []
    for i in find_li :
        find_a = i.find('a')
        url = find_a.get('onclick')
        url = str(url)
        url_ = re.findall("\d+", url)
        recipe_url.append(url_[-1])

    ## title 가져오기
    for i in recipe_url :
        try:
            url_num = i
            resp = requests.request("GET", 'http://www.chungjungone.com/knowhow/recipe/recipeView1New.do?s_str={}&recp_kind_cd=&recp_kind_cd_nm=&recp_situ_cd=&recp_situ_cd_nm=&x=0&y=0&recp_seq={}'.format(url_str,url_num)) 
            soup = BeautifulSoup(resp.text)
            find_div = soup.find('div', class_ = 'editRecipy')
            find_h2 = find_div.find('h2')
            title = find_h2.text

            find_ul = soup.find('ul', class_ = 'reInfo')
            span_list = []
            for i in find_ul :
                find_span = i.find('span')
                span_list.append(find_span)

            ## keyword 가져오기(몇분/난이도)
            keyword = []
            for i in span_list[1:8:2] :
                i = str(i)
                i = i[6:]
                i = i.split('<')
                data = i[0]
                if '조리' in data:
                    i = data[3:]
                    keyword.append(i)
                else :
                    keyword.append(data)

            for i in keyword :
                if "분" in i :
                    if '인' not in i :
                        time = i
                elif ("급") in i :
                    level = i
                else :
                    pass

            # 재료 가져오기

            source = []
            find_div = soup.find('div', class_ = 'texAlCenter')
            find_div = str(find_div)
            find_div = find_div.replace('<br/>', ',').replace('</div>', '').replace('<div class="texAlCenter">', '').replace(':', ',').replace(',,', ',')
            source.append(find_div)

            list_ = source[0].split(',')
            for i in list_ :
                if '소스' in i :
                    list_.remove(i)
            ingredient = []
            for i in list_ :
                i = i.strip()
                if len(i) == 0 :
                    pass
                else : 
                    ingredient.append(i)
                    
            recipe.append({
                'title' : title,
                'url' : 'http://www.chungjungone.com/knowhow/recipe/recipeView1New.do?s_str={}&recp_kind_cd=&recp_kind_cd_nm=&recp_situ_cd=&recp_situ_cd_nm=&x=0&y=0&recp_seq={}'.format(url_str,url_num),
                'time' : time,
                'level' : level,
                'ingredient' : ingredient
            })

        except :
            continue

    return recipe


##만개의 레시피
def get_recipe2(have_list):
    
    base_url='https://www.10000recipe.com/recipe/list.html'

    have_list1 = "+".join(have_list) 
    food = " ".join(have_list)
    
    params={
        'q':food
    }
    
    resp=requests.get(base_url,params=params)
    soup=BeautifulSoup(resp.text)    
    
    
    url_list=[]
    title_list=[]
    result_list=[]
    
    recipe_list_tags=soup.select('ul.common_sp_list_ul.ea4')
    li_tags=recipe_list_tags[0].find_all('li')

    
    for li in tqdm_notebook(li_tags):
        anchor_tag=li.find('a')
        href=anchor_tag.get('href')
        title_tag=li.find_all('div',class_='common_sp_caption_tit line2')
        
        result_list.append({'title':title_tag,
                           'url':href})
        
        url_list.append(href)
        for title in title_tag:
            title_list.append(title.text.strip())
    
    
    url_list2=[]
    for url in url_list:
        each_url='https://www.10000recipe.com'+url
        url_list2.append(each_url)
        
    span1=[]
    span2=[]
    span3=[]
    for url in tqdm_notebook(url_list):
        each_url='https://www.10000recipe.com'+url

        resp=requests.get(each_url)
        soup=BeautifulSoup(resp.text)

        desc_list_tags=soup.select('div.view2_summary_info')

        for desc in desc_list_tags:
            span_tag=desc.select('span')
            if len(span_tag) == 3:
                time = span_tag[1].text
                lev = span_tag[2].text
                span2.append(time)
                span3.append(lev)
            
            elif not span_tag:
                span2.append(None)
                span3.append(None)

            else:
                time=None
                lev = span_tag[0]
                span2.append(time)
                span3.append(lev)

    ing_list=[]
    li_list=[]
    for url in url_list:
        each_url='https://www.10000recipe.com'+url

        resp=requests.get(each_url)
        soup=BeautifulSoup(resp.text)

        ing_list_tags=soup.select('div.ready_ingre3')
        cont_tags=soup.select('div.cont_ingre')

        for i in ing_list_tags:
            li_tags=i.find_all('li')
            li_list.append(li_tags)

        for j in cont_tags:
            dd_tags=j.find_all('dd')
            li_list.append(dd_tags)
            
    ingr_list=[]
    for i in tqdm_notebook(li_list):
        temp = []
        for j in i:
            all_ing=j.text.replace(' ','').strip().split('\n')
            all_ing = " ".join(all_ing)
            temp.append(all_ing)
        ingr_list.append(temp) 
        temp=[]
        
    df=pd.DataFrame({'title':title_list,
                     'url':url_list2,
                     'time':span2,
                     'level':span3,
                     'ingredient':ingr_list})
    
    return df

## 해먹남녀
def get_recipe3(have_list,page_num=2):
    have_list1 = "+".join(have_list) ## "양파 가지"
    have_list2 = " ".join(have_list)
    url = 'https://www.haemukja.com/recipes?utf8=%E2%9C%93&sort=rlv&name={}'.format(have_list1)
    result_list = []
    
    for i in range(page_num):
        params = {
            'name': have_list2,
            'page': 1,
            'sort': 'rlv'
         }

        resp = requests.get(url, params = params)
        resp

        soup = BeautifulSoup(resp.text)

        titles = soup.select('ul.lst_recipe>li>p>a')

        for a_tag in titles:

            recipe_url = 'https://www.haemukja.com'+ a_tag.get('href')
            detail_resp = requests.get(recipe_url)
            html = BeautifulSoup(detail_resp.text)

            prd_time = str(html.select('div.top>dl>dd'))
            prd_time = re.sub('<.+?>', '', prd_time, 0).strip()
            prd_sources = str(html.select('div.btm>ul>li'))
            prd_sources=re.sub('<.+?>', '', prd_sources,0)

            result_list.append({
                'title': (a_tag.text.split('\n')[1]).strip(),
                'url': recipe_url,
                'time':prd_time.replace('[','').replace(']','').split(',')[0],
                'level': 'null',
                'ingredient': prd_sources.replace('[','').replace(']','').split(',')
            })       

        return result_list 

have_list = []
have = input("가진 재료 :")
while have != '끝' :
    have_list.append(have)
    have = input("가진 재료 :")
    
## 각 함수들의 리턴값인 데이터프레임형태의 레시피리스트를 concat하여 하나의 데이터프레임으로 저장
data1 = get_recipe1(have_list)
data1 = pd.DataFrame(data1)
data2 = get_recipe2(have_list)
data3 = get_recipe3(have_list)
data3 = pd.DataFrame(data3)
if len(data1['title'][0]) == 0 :
    menu = pd.concat([data2,data3])
else :
    menu = pd.concat([data1,data2,data3])
menu.reset_index(drop=True,inplace=True)
menu ## 최종 레시피 리스트
# Out:
# 가진 재료 :소고기
# 가진 재료 :달걀
# 가진 재료 :후추
# 가진 재료 :끝
# HBox(children=(FloatProgress(value=0.0, max=40.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=40.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=40.0), HTML(value='')))
#                                                 title  \
# 0                                       백종원의 부추 달걀 볶음
# 1                             소고기 배춧국 만들기 든든한 한끼로 제격!
# 2                               간단요리 계란 양파덮밥 혼밥 자취레시피
# 3                                      매콤 소시지 달걀 치즈구이
# 4                                           소고기 대파 볶음
# 5   [No.3 양배추 소고기 덮밥] 겨울의 외로움으로부터 힐링시켜주는 따듯한 덮밥 / ...
# 6                                      소고기 감자조림 일본가정식
# 7          백종원 부추 달걀 볶음 황금레시피 ,, 초간단 중국식 인기 메뉴 맛있어요~!
# 8                      초간단 아침식사, 카레향 나는 두부 달걀 스크램블 덮밥
# 9            수미네 반찬 소고기 뭇국 끓이기. 경상도식이 더 맛있네~ 간단한 국 요리
# 10                                       당면 계란 만두 전~*
# 11                       계란 새우볶음밥 만들기 굴소스로 쉽게 만들어요 ^^
# 12                                계란 참치주먹밥 소풍도시락 간단요리
# 13                           술술 부드럽게 넘어가는 우유 계란 카레 덮밥
# 14                                 진정한 밥도둑 소고기 볶음 고추장
# 15                                         소고기 파프리카말이
# 16                           소고기 보다 맛있고 쫄깃쫄깃한 표고버섯 볶음
# 17                             숙주요리 계란 새우 숙주볶음 초간단반찬!
# 18                                 밥반찬 애호박 소고기 부채살 볶음
# 19                              소고기요리 소고기 초밥 배합초 최고예요
# 20                          식빵 토스트, 든든한 소시지 달걀 치즈 토스트
# 21                                       얼큰한~ 소고기 감자국
# 22  초간단 다이어트 요리!! 양배추 계란 덮밥 만들기 (단백질 40.89kcal, 지방...
# 23        간단한 볶음요리!집밥 백선생의 부추 달걀 볶음레시피! 중국식 계란볶음만들봐요~
# 24                             버터링 쿠키(노에그, 계란 없이 베이킹)
# 25             인기메뉴 한그릇 혼밥 ,, 초스피드 매콤 소고기 덮밥 황금레시피 ~!
# 26                                    사과 달걀 스크램블 브런치로
# 27                       여름제철 감자요리/간단 브런치로 좋은 계란 감자채전
# 28                     김밥보다 간편하고 맛있다! 소고기 주먹밥 만들기 레시피
# 29                                  집에서 소고기 찹스테이크 만들기
# 30                                          쇠고기 달걀 덮밥
# 31                                         소시지 달걀 치즈전
# 32                 척 아이롤과 홀 토마토를 넣은 다이어트 소고기 스튜(비프스튜)
# 33                              카레향 솔솔 나는 시금치 달걀 카레죽♪
# 34                             엄마의 레시피, 소고기 미역국 끓이는 법
# 35                                 백종원 레시피 계란 덮밥 만들기!
# 36                        소고기 듬뿍 넣은 약고추장으로 봄철 입맛 살리기!
# 37                           계란 치즈 볶음밥, 아침메뉴, 초간단 볶음밥
# 38                            간단 5분 요리 계란 크래미 게맛살 볶음밥
# 39                          달걀 연유 토스트 - 아이 간식 토스트 만들기
# 40                             소고기 볶음 고추장ㅣ밥 열공기 뚝!딱!ㅣ
# 41                           들어는 봤니 경상도식 얼큰 시원 소고기 무국
# 42                                   향긋한 봄내음, 소고기달래무국
# 43                                         소고기 만두 만들기
# 44                          간장 소스는 이제 그만, 이그조틱 소고기 덮밥
# 45                                       깊은 고기 육수맛을 낸
# 46                          소고기 무국 레시피ㅣ진한 국물 맛이 일품인!ㅣ
# 47                 완료기이유식 아기 소고기 카레 만들기 (만13개월 아기 반찬)
# 48                                   스테이크 초밥 ‘소고기 초밥’
# 49                         겨울철 잘 끓인 소고기 무국 곰국 한솥 안부럽다
# 50                                   소고기된장찌개 황금레시피 !!
# 51                                  한끼의 품격, 고소한 소고기덮밥
#
#                                            url    time  level  \
# 0   https://www.10000recipe.com/recipe/6891606  15분 이내    아무나
# 1   https://www.10000recipe.com/recipe/6880695  30분 이내    아무나
# 2   https://www.10000recipe.com/recipe/6920148  10분 이내    아무나
# 3   https://www.10000recipe.com/recipe/6916782   5분 이내    아무나
# 4   https://www.10000recipe.com/recipe/6899457  15분 이내     초급
# 5   https://www.10000recipe.com/recipe/6841467  30분 이내     초급
# 6   https://www.10000recipe.com/recipe/6828936    None   [초급]
# 7   https://www.10000recipe.com/recipe/6871467  10분 이내    아무나
# 8   https://www.10000recipe.com/recipe/6908353  10분 이내    아무나
# 9   https://www.10000recipe.com/recipe/6934526  60분 이내    아무나
# 10  https://www.10000recipe.com/recipe/6865345  15분 이내    아무나
# 11  https://www.10000recipe.com/recipe/6891445  15분 이내     초급
# 12  https://www.10000recipe.com/recipe/6920843  10분 이내     초급
# 13  https://www.10000recipe.com/recipe/6926683  10분 이내     초급
# 14  https://www.10000recipe.com/recipe/6838094  15분 이내     초급
# 15  https://www.10000recipe.com/recipe/6796725  30분 이내     초급
# 16  https://www.10000recipe.com/recipe/6903513  15분 이내    아무나
# 17  https://www.10000recipe.com/recipe/6890250  15분 이내    아무나
# 18  https://www.10000recipe.com/recipe/6934243  30분 이내     초급
# 19  https://www.10000recipe.com/recipe/6832489  30분 이내     초급
# 20  https://www.10000recipe.com/recipe/6911250  10분 이내    아무나
# 21  https://www.10000recipe.com/recipe/6869294  30분 이내    아무나
# 22  https://www.10000recipe.com/recipe/6932039  20분 이내    아무나
# 23  https://www.10000recipe.com/recipe/6898178   5분 이내    아무나
# 24  https://www.10000recipe.com/recipe/6876723  60분 이내    아무나
# 25  https://www.10000recipe.com/recipe/6871754  15분 이내    아무나
# 26  https://www.10000recipe.com/recipe/6923152  10분 이내    아무나
# 27  https://www.10000recipe.com/recipe/6894202  30분 이내     초급
# 28  https://www.10000recipe.com/recipe/6915277  30분 이내    아무나
# 29  https://www.10000recipe.com/recipe/6937768  30분 이내     초급
# 30  https://www.10000recipe.com/recipe/4195367    None  [아무나]
# 31  https://www.10000recipe.com/recipe/6914883  10분 이내    아무나
# 32  https://www.10000recipe.com/recipe/6910792  30분 이내    아무나
# 33  https://www.10000recipe.com/recipe/6871302  30분 이내    아무나
# 34  https://www.10000recipe.com/recipe/6873683  60분 이내     초급
# 35  https://www.10000recipe.com/recipe/6833211  15분 이내     초급
# 36  https://www.10000recipe.com/recipe/6866075  30분 이내     초급
# 37  https://www.10000recipe.com/recipe/6854270   5분 이내     초급
# 38  https://www.10000recipe.com/recipe/6928754   5분 이내    아무나
# 39  https://www.10000recipe.com/recipe/6908834  60분 이내    아무나
# 40       https://www.haemukja.com/recipes/5910     30분   null
# 41       https://www.haemukja.com/recipes/2261     40분   null
# 42       https://www.haemukja.com/recipes/2232     75분   null
# 43        https://www.haemukja.com/recipes/190     80분   null
# 44       https://www.haemukja.com/recipes/1084     30분   null
# 45       https://www.haemukja.com/recipes/4608     20분   null
# 46       https://www.haemukja.com/recipes/5913     20분   null
# 47        https://www.haemukja.com/recipes/334     25분   null
# 48       https://www.haemukja.com/recipes/4343     15분   null
# 49       https://www.haemukja.com/recipes/5390   30분~분   null
# 50        https://www.haemukja.com/recipes/638     25분   null
# 51       https://www.haemukja.com/recipes/3660     20분   null
#
#                                            ingredient
# 0    [부추 1줌, 달걀 4개, 식용유 2큰술, 밥 2공기, 굴소스 1큰술, 참기름 1큰술]
# 1   [배추잎 5~6장, 소고기국거리 200g, 다진마늘 1/2스푼, 파 조금, 국간장 ...
# 2     [양파 1/2개, 계란 2개, 간장 2스푼, 맛술 2스푼, 설탕 1스푼, 물 6스푼]
# 3   [비엔나소시지 8개, 달걀 1개, 청양고추 1개, 다진양파 3큰술, 식용유 1큰술,...
# 4   [한우소고기(살치살) 200g, 대파(흰부분) 1컵, 식용유 2큰술, 간장 1작은술...
# 5   [소고기, 양배추, 쌀, 전분가루, 굴소스 0.5숟갈, 간장 1숟갈, 다진마늘 0....
# 6   [소고기불고기용 300g, 감자 4개, 청고추 2개, 홍고추 2개, 물 1머그컵, ...
# 7           [계란 3개, 부추 1줌, 굴소스 1큰술, 참기름 1큰술, 식용유 적당량]
# 8   [두부 1모, 달걀 8개, 카레가루 2T, 우유 200ml, 소금 4꼬집, 후추 취...
# 9   [소고기국거리용 1주먹, 무 1/2개, 대파 1대, 다진마늘 1T, 고춧가루 3t,...
# 10            [당면50g,계란2개,대파반,당근조금, 굴소스(티스푼)1,후추(톡톡)]
# 11  [밥 2공기, 양파 1/2개, 대파 1/2대, 당근 1/3개, 계란 3개, 굴소스 ...
# 12  [밥 1공기, 참치한캔 100g, 계란 2개, 소금 3꼬집, 후추 1/2스푼, 대파...
# 13  [카레가루 3~3+1/2스푼, 우유 200ml, 계란 1개, 양파 1/2개, 햄 1...
# 14  [갈은소고기 480g, 양파 2개, 고추장 9T, 다진마늘 2T, 후추 1T, 간장...
# 15  [소고기불고기감 150g, 파프리카 1개, 깻잎 10장, 간장 2숟갈, 매실청 1숟...
# 16  [표고버섯 10개, 양파 1/2개, 당근 1/4개, 진간장 1스푼, 굴소스 1스푼,...
# 17  [숙주 2-3줌, 계란 2개, 새우 10마리, 양파 1/2개, 청양고추 1개, 대파...
# 18  [소고기부채살 150g, 애호박 1/2개, 소금 1작은술, 양파 1/2개, 식용유 ...
# 19  [양파 1/4개, 무순 조금, 등심, 안심, 홍두깨살200g, 간장 4T, 올리고당...
# 20  [식빵 1장, 버터 1큰술, 달걀 1개, 채썬당근 2꼬집, 송송썬파 2꼬집, 모짜렐...
# 21  [중간크기감자 2개, 참기름 1큰술, 식용유 1큰술, 다진마늘 1큰술, 대파 1대,...
# 22  [현미밥 1/2개, 계란 1개, 닭가슴살소세지 1팩, 양배추 1/4개, 칵테일새우 ...
# 23            [달걀 3개, 부추 1줌, 굴소스 1T, 참기름 1/2T, 후추 약간]
# 24                   [박력분 80g, 설탕 30g, 버터 60g, 우유 2T]
# 25  [소고기 150그램, 양파 1/2개, 고추장 1큰술, 매운고춧가루 1큰술, 굴소스 ...
# 26  [달걀 2개, 사과 1/4개, 모짜렐라치즈 60g, 파슬리가루 약간, 식용유 약간,...
# 27  [감자 2개, 계란 2개, 슬라이스치즈 1장, 소금 1꼬집, 후추 약간, 찹쌀가루 ...
# 28  [쇠고기 200g, 호박 1/4, 파프리카 1/4, 당근 1/4, 양파 1/3, 밥...
# 29  [소고기등심 300g, 양파 1/2개, 빨간파프리카 1/2개, 노란파프리카 1/2개...
# 30  [소고기불고기감 100g, 양파주먹크기 1/2개, 대파 2/3개, 달걀 2개, 팽이...
# 31  [남양3층카야치즈 1장, 달걀 2개, 그릴비엔나소시지 4개, 대파 약간, 식용유 약...
# 32  [소고기 150g, 홀토마토 400g, 양파 1개, 당근 50g, 소금 조금, 후추...
# 33  [찬밥 2공기, 시금치 2줌, 달걀 2개, 새송이버섯 1개, 양파 1/2개, 당근 ...
# 34  [소고기(국거리용) 180g, 미역 1줌(20g), 쌀뜨물(혹은물) 1.4L(종이컵...
# 35                   [계란 3알, 진간장 2스푼, 고추가루 1스푼, 파 1대]
# 36  [다진소고기 200g, 양파 1/4개, 대파 10cm, 간장 1T, 설탕 0.3T,...
# 37       [달걀 2개, 치즈 1장, 식용유 2T, 맛소금 약간, 후추 약간, 간장 1T]
# 38                [크래미 2-3개, 대파 1/2개, 굴소스 1스푼, 계란 1개]
# 39                  [식빵 4장, 달걀 2개, 우유 4, 연유 4, 소금 약간]
# 40  [다진 소고기300g,  해물 다시팩 육수400ml,  고추장2종이컵,  다진 파6...
# 41  [무약간,  국거리용 소고기한팩,  콩나물한봉지,  양파한개,  대파한개,  고춧가...
# 42              [소고기우둔살300g,  달래100g,  무100g,  쪽파2뿌리]
# 43  [소고기,  양파1 개(대),  두부1 모,  당면한줌,  마늘2 숟가락,  숙주,...
# 44  [버섯 (모든 종류)300 g,  소고기 등심400 g,  마늘3 쪽,  플레인요거...
# 45   [쇠고기 양지100g,  무200g,  대파1/3대,  다진마늘1큰술,  국간장1큰술]
# 46  [소고기300g,  무1/3개,  파1/2개,  통후추약간,  소금2작은술,  국간...
# 47  [카레가루25 g,  감자10 g,  양파10 g,  당근10 g,  표고버섯10 ...
# 48  [한우 채끝200g,  밥3인분,  양파1/6개,  실파1개,  스테이크소스30g,...
# 49  [국거리소고기한팩,  무2컵,  다진마늘1큰술,  소금,  후추약간,  국간장3큰술...
# 50  [물4 컵,  된장2 숟가락,  고추장1/2 숟가락,  다진마늘1 작은술,  양파1...
# 51  [소고기등심150g,  시금치2줄기,  표고버섯3개,  다진마늘1/2작은술,  올리...

# %%
menu['ingredient'][20]
# Out:
# ['식빵 1장',
#  '버터 1큰술',
#  '달걀 1개',
#  '채썬당근 2꼬집',
#  '송송썬파 2꼬집',
#  '모짜렐라치즈 적당량',
#  '소금 2꼬집',
#  '후추 2꼬집',
#  '설탕 2꼬집']

# %%
def online_market(recipe_num) :
    recipe_num = int(recipe_num)
    selected_recipe = menu.iloc[recipe_num:recipe_num+1, :]
    selected_ing = selected_recipe['ingredient'].tolist()
    selected_ing = selected_ing[0]
    
    ## 필요한 재료(선택 레시피에는 있지만 내가 가지지 못한 재료) 추출
#     no_matter = []
    print("선택한 레시피의 재료들 :" ,selected_ing) 
    print("사용자가 가지고 있는 재료들 :", have_list)
    
    for i in selected_ing :
        if ('조금' in str(i)) or ('용' in str(i)):
            pass
        else :
            list1 = i.split(' ')
            a = list1[0]
            if a in have_list : 
                try :
                    b = ' '.join(list1)
                    selected_ing.remove(b)
                except :
                    pass

    no_matter = []
    for i in selected_ing :
        a = i.split(' ')
        no_matter.append(a[0])
        
    print("선택한 레시피의 재료 중에 사용자에게 없는 재료들 :", no_matter)
    
#     path = "C:\\Users\\dayoung\\Downloads\\chromedriver_win32\\chromedriver"
#     driver = webdriver.Chrome(path)
    driver = webdriver.Chrome()
    
    ## 마켓컬리 사이트 로그인
    driver.get("https://www.kurly.com/shop/member/login.php")
    element_id = driver.find_element_by_name("m_id")
    element_pw = driver.find_element_by_name("password")
    element_id.send_keys("ldyoung")
    element_pw.send_keys("dlsrhdwlsmd1234")
    driver.find_element_by_class_name('btn_type1').click()

    element_input = driver.find_element_by_name("sword")
    element_input.clear()

    ## 검색창 접근
    for want in no_matter:
        sword = driver.find_element_by_name('sword')  # 검색창
        sword.clear()  # 검색창에 쓰여진것 지우기
        sword.send_keys(want)  # 재료 리스트 입력
        btn_search = driver.find_elements_by_class_name('btn_search')[0]
        btn_search.click()  # '검색버튼' 클릭

        # 장바구니 클릭
        driver.implicitly_wait(100000)
        xpath = driver.find_element_by_xpath('//*[@id="goodsList"]/div[1]/div/ul/li[1]/div/div/div/button')
        xpath.click()

        # 장바구니 큰 틀
        inner_option = driver.find_elements_by_class_name('inner_option')[0]

        # 장바구니 추가 버튼
        final = inner_option.find_element_by_class_name('btn_type1')

        # 옵션 이름 리스트
        name = inner_option.find_elements_by_class_name('name')   
        name_list = []
        for i in name:
            name_list.append(i.text)

        for idx, item in enumerate(name_list):
            if len(name_list) == 1:  # name_list의 길이가 1인 경우

                if '품절' not in item:
                    final.click()
                else:
                    btn_close = driver.find_element_by_class_name('btn_close1')[0]  # 장바구니 닫기
                    btn_close.click()
                    break  # 첫번째 for문으로 돌아가야 하는데 맞나?????????????????

            else: # name_list의 길이가 2 이상인 경우
                if '품절' not in item:

                    if want in item:
                        button_up = inner_option.find_elements_by_css_selector('.btn.up')[idx]  # 수량 올리기
                        button_up.click()
                        final.click()  # 장바구니 담기
                        ## 첫번째 for문으로 다시 돌아가야 하는데 맞나????????

                    else:
                        button_up = inner_option.find_elements_by_css_selector('.btn.up')[0]  # 첫번째 항목 수량 올리기
                        button_up.click()
                        final.click()  # 장바구니 P담기

                    break

                else:  # 품절이 항목에 있는 경우

                    if '품절' in item:
                        pass
                    elif want in item:
                        button_up = inner_option.find_elements_by_css_selector('.btn.up')[idx]  # 수량 올리기
                        button_up.click()
                        final.click()  # 장바구니 담기
                        break
                    else:    
                        button_up = inner_option.find_elements_by_css_selector('.btn.up')[0]  # 첫번째 항목 수량 올리기
                        button_up.click()
                        final.click()  # 장바구니 담기
                        break
                    
recipe_num = int(input("레시피 번호 선택 : "))
result = online_market(recipe_num)
# Out:
# 레시피 번호 선택 : 12
# 선택한 레시피의 재료들 : ['밥 1공기', '참치한캔 100g', '계란 2개', '소금 3꼬집', '후추 1/2스푼', '대파 1개']
# 사용자가 가지고 있는 재료들 : ['소고기', '달걀', '후추']
# 선택한 레시피의 재료 중에 사용자에게 없는 재료들 : ['밥', '참치한캔', '계란', '소금', '대파']
