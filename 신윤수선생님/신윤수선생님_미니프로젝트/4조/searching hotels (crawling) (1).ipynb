# %% [markdown]
# # 에어비앤비 크롤링

# %%
import requests
from bs4 import BeautifulSoup as bs
import urllib
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 맷플롯립 한글 폰트 지정
import platform
from matplotlib import font_manager, rc

# 한글 설정시 마이너스 부호 깨지는 것 방지
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    # mac
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    # windows
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
url="https://www.airbnb.co.kr/s/%EC%A0%9C%EC%A3%BC%EB%8F%84/homes?query=%EC%A0%9C%EC%A3%BC%EB%8F%84&federated_search_session_id=e296e38b-6ec1-4296-9a81-f762cfb2c92a&source=structured_search_input_header&search_type=pagination&tab_id=home_tab&checkin=2020-08-16&refinement_paths%5B%5D=%2Fhomes&checkout=2020-08-17&place_id=ChIJRUDITFTjDDURMb8emNI2vGY&section_offset=2&items_offset=0"
url_parsed=urllib.parse.urlparse(url)

url_qs=urllib.parse.parse_qs(url_parsed.query)

# %%
url_qs
# Out:
# {'query': ['제주도'],
#  'federated_search_session_id': ['e296e38b-6ec1-4296-9a81-f762cfb2c92a'],
#  'source': ['structured_search_input_header'],
#  'search_type': ['pagination'],
#  'tab_id': ['home_tab'],
#  'checkin': ['2020-08-16'],
#  'refinement_paths[]': ['/homes'],
#  'checkout': ['2020-08-17'],
#  'place_id': ['ChIJRUDITFTjDDURMb8emNI2vGY'],
#  'section_offset': ['2'],
#  'items_offset': ['0']}

# %%
base_url="https://www.airbnb.co.kr/s/%EC%A0%9C%EC%A3%BC%EB%8F%84/homes"
params={'query': '제주도',
 'federated_search_session_id': 'e296e38b-6ec1-4296-9a81-f762cfb2c92a',
 'source': 'structured_search_input_header',
 'search_type': 'pagination',
 'tab_id': 'home_tab',
 'checkin': '2020-08-16',
 'refinement_paths[]': '/homes',
 'checkout': '2020-08-17',
 'place_id': 'ChIJRUDITFTjDDURMb8emNI2vGY',
 'section_offset': '2',
 'items_offset': '0'}

# %%
resp=requests.get(base_url,params=params)
resp

soup=bs(resp.text)

item_tags=soup.select("#FMP-target > div > div > div > div")
len(item_tags[0])
# Out:
# <Response [200]>

# %%
a_tags=item_tags[0].find_all("a")

url_list=[]
for i in a_tags:
    url_list.append("https://www.airbnb.co.kr%s" %i.get("href"))
    
url_list
# Out:
# ['https://www.airbnb.co.kr/rooms/19724369?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/36090662?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/15321610?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/18103390?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/43298030?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/5933890?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/33958148?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/15639787?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/43834942?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/33031867?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/22852031?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/16491566?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/43659982?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/24053473?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/41779774?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/43409657?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/44234403?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/20395764?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/7894631?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9',
#  'https://www.airbnb.co.kr/rooms/29660036?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9']

# %%
price_tags=item_tags[0].find_all("span", class_="_1p7iugi")

price_list=[]

for i in price_tags:
    try:
        price=i.text.split(":")[2]
    except:
        price=i.text.split(":")[1]
        
    price_list.append(price)
    
price_list
# Out:
# ['₩44,100',
#  '₩51,988',
#  '₩34,543',
#  '₩35,814',
#  '₩34,659',
#  '₩80,870',
#  '₩67,654',
#  '₩103,977',
#  '₩57,765',
#  '₩46,212',
#  '₩34,659',
#  '₩34,659',
#  '₩144,412',
#  '₩83,181',
#  '₩43,900',
#  '₩92,423',
#  '₩288,823',
#  '₩19,640',
#  '₩39,280',
#  '₩25,417']

# %%
count_reviews=item_tags[0].find_all("span",class_="_krjbj")

count_reviews

count_reviews_list=[]
for i in count_reviews:
    if "후기" in str(i):
        count_reviews_list.append(i.text.split(" ")[1])
        
count_reviews_list
# Out:
# ['702개',
#  '36개',
#  '63개',
#  '70개',
#  '10개',
#  '64개',
#  '44개',
#  '317개',
#  '8개',
#  '15개',
#  '54개',
#  '188개',
#  '96개',
#  '156개',
#  '7개',
#  '121개',
#  '57개',
#  '14개']

# %%
name_tags=item_tags[0].find_all("div",class_="_1c2n35az")
rate_tags=item_tags[0].find_all("span",class_="_10fy1f8")


result=[]
for n,r,u,p,c in zip(name_tags,rate_tags,url_list,price_list,count_reviews_list):
    result.append({
        "이름":n.text,
        "평점":r.text,
        "후기 개수" :c,
        "가격":p,
        "링크":u
    })
    
result
# Out:
# [{'이름': '[플레이스캠프제주] Standard',
#   '평점': '4.47',
#   '후기 개수': '702개',
#   '가격': '₩44,100',
#   '링크': 'https://www.airbnb.co.kr/rooms/19724369?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '법환동 바닷가집 별채',
#   '평점': '4.86',
#   '후기 개수': '36개',
#   '가격': '₩51,988',
#   '링크': 'https://www.airbnb.co.kr/rooms/36090662?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '몽돌하우스',
#   '평점': '4.84',
#   '후기 개수': '63개',
#   '가격': '₩34,543',
#   '링크': 'https://www.airbnb.co.kr/rooms/15321610?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '걷기 좋은 동네 게스트하우스',
#   '평점': '4.61',
#   '후기 개수': '70개',
#   '가격': '₩35,814',
#   '링크': 'https://www.airbnb.co.kr/rooms/18103390?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '애몽게스트하우스) 애월해안도로 도보3분거리_#5프라이빗한 도미토리방(여성only)6인실',
#   '평점': '4.90',
#   '후기 개수': '10개',
#   '가격': '₩34,659',
#   '링크': 'https://www.airbnb.co.kr/rooms/43298030?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '협재 인 제주 inn JEJU 지금의 방 & Breakfast',
#   '평점': '4.72',
#   '후기 개수': '64개',
#   '가격': '₩80,870',
#   '링크': 'https://www.airbnb.co.kr/rooms/5933890?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '한라산 오름 등반 최적 힐링 숙소 제주 수스테이 302',
#   '평점': '4.75',
#   '후기 개수': '44개',
#   '가격': '₩67,654',
#   '링크': 'https://www.airbnb.co.kr/rooms/33958148?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': "#2 / JW's House 2 (독채)",
#   '평점': '4.68',
#   '후기 개수': '317개',
#   '가격': '₩103,977',
#   '링크': 'https://www.airbnb.co.kr/rooms/15639787?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '가장 합리적인 제주 여행자를 위한 숙소.Cornerstone Hotel 스탠다드 더블',
#   '평점': '4.38',
#   '후기 개수': '8개',
#   '가격': '₩57,765',
#   '링크': 'https://www.airbnb.co.kr/rooms/43834942?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '오늘,하루 - 1인실',
#   '평점': '4.87',
#   '후기 개수': '15개',
#   '가격': '₩46,212',
#   '링크': 'https://www.airbnb.co.kr/rooms/33031867?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '말레콘 감귤룸(개별욕실,시디&만화책)',
#   '평점': '4.79',
#   '후기 개수': '54개',
#   '가격': '₩34,659',
#   '링크': 'https://www.airbnb.co.kr/rooms/22852031?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '불특정식당(손님전용민박)#1',
#   '평점': '4.63',
#   '후기 개수': '188개',
#   '가격': '₩34,659',
#   '링크': 'https://www.airbnb.co.kr/rooms/16491566?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': 'Emily house',
#   '평점': '4.50',
#   '후기 개수': '96개',
#   '가격': '₩144,412',
#   '링크': 'https://www.airbnb.co.kr/rooms/43659982?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '감성 제주, 걷기좋은 돌담길 올레2코스와 어우러진 농가주택[우붓-우리가품은 공간]-나비잠',
#   '평점': '4.37',
#   '후기 개수': '156개',
#   '가격': '₩83,181',
#   '링크': 'https://www.airbnb.co.kr/rooms/24053473?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '디럭스 트윈 더블',
#   '평점': '4.57',
#   '후기 개수': '7개',
#   '가격': '₩43,900',
#   '링크': 'https://www.airbnb.co.kr/rooms/41779774?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': "함덕해수욕장 근처 바다 앞 제주스런 커플동 ‘신흥부부 청보리동'",
#   '평점': '4.62',
#   '후기 개수': '121개',
#   '가격': '₩92,423',
#   '링크': 'https://www.airbnb.co.kr/rooms/43409657?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '[신축]개별마당과 수영장이 있는 독채 _제주라피아하우스/노꼬메룸',
#   '평점': '4.71',
#   '후기 개수': '57개',
#   '가격': '₩288,823',
#   '링크': 'https://www.airbnb.co.kr/rooms/44234403?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'},
#  {'이름': '제주에서 제일 싼 개인실/ 개별욕실/ 가성비갑 G',
#   '평점': '4.71',
#   '후기 개수': '14개',
#   '가격': '₩19,640',
#   '링크': 'https://www.airbnb.co.kr/rooms/20395764?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=d8ab127c-7d64-4fce-a573-0fdc5452e4c9'}]

# %%
aa_parsed=urllib.parse.urlparse("https://www.airbnb.co.kr/s/%EC%A0%9C%EC%A3%BC%EB%8F%84/homes?tab_id=home_tab&checkin=2020-08-16&refinement_paths%5B%5D=%2Fhomes&source=structured_search_input_header&checkout=2020-08-17&search_type=pagination&federated_search_session_id=84129821-dfaf-4829-8d0e-55b87780b004&query=%EC%A0%9C%EC%A3%BC%EB%8F%84&place_id=ChIJRUDITFTjDDURMb8emNI2vGY&section_offset=3&items_offset=20")

# %%
aa_query=urllib.parse.parse_qs(aa_parsed.query)
aa_query
# Out:
# {'tab_id': ['home_tab'],
#  'checkin': ['2020-08-16'],
#  'refinement_paths[]': ['/homes'],
#  'source': ['structured_search_input_header'],
#  'checkout': ['2020-08-17'],
#  'search_type': ['pagination'],
#  'federated_search_session_id': ['84129821-dfaf-4829-8d0e-55b87780b004'],
#  'query': ['제주도'],
#  'place_id': ['ChIJRUDITFTjDDURMb8emNI2vGY'],
#  'section_offset': ['3'],
#  'items_offset': ['20']}

# %% [markdown]
# # 에어비앤비 크롤링 함수화

# %%
def airbnb(place,checkin,checkout,pages):  #place = 장소, checkin = 체크인 날짜, checkout :체크아웃 날짜, pages=검색하고자 하는 페이지 수
    
    
    result_list=[]  #크롤링 최종 결과를 담을 리스트
    
    #에어비앤비는 offset이 20단위로 페이지가 변화 ex)offset 0 : 1페이지 , offset 1~20: 2페이지 
    for page in range(1,pages+1): #입력받은 페이지 수만큼 모두 크롤링 하기 위해
        if page==1:  #page가 1이면 offset=0
            offset=0
        else:
            offset=page*20  #1보다 크면 page*20
    
    
        #리퀘스트할 url과 파라미터 설정
        base_url="https://www.airbnb.co.kr/s/%s/homes" %place
        params={
         'source': 'structured_search_input_header',
         'search_type': 'pagination',
         'tab_id': 'home_tab',
         'checkin': checkin,
         'refinement_paths[]': '/homes',
         'checkout': checkout,
         'section_offset': '2',
         'items_offset': offset}
        
        resp=requests.get(base_url,params=params)
        soup=bs(resp.text)
        item_tags=soup.select("#FMP-target > div > div > div > div")
        len(item_tags[0])

        
        #해당 숙소에 대한 상세페이지 url을 가져옴
        a_tags=item_tags[0].find_all("a")
        url_list=[]
        for i in a_tags:
            url_list.append("https://www.airbnb.co.kr%s" %i.get("href"))


        #숙소들의 가격정보를 가져옴
        price_tags=item_tags[0].find_all("span", class_="_1p7iugi")
        price_list=[]
        for i in price_tags:
            try:
                price=i.text.split(":")[2]
            except:
                price=i.text.split(":")[1]

            price_list.append(price.replace("₩",""))

        #숙소들의 리뷰 개수를 가져옴
        count_reviews=item_tags[0].find_all("span",class_="_krjbj")
        count_reviews
        count_reviews_list=[]
        for i in count_reviews:
            if "후기" in str(i):
                count_reviews_list.append(i.text.split(" ")[1])

        #숙소들의 이름과 평점을 가져옴
        name_tags=item_tags[0].find_all("div",class_="_1c2n35az")
        rate_tags=item_tags[0].find_all("span",class_="_10fy1f8")
        
        result=[]
        
        #앞에서 추출한 정보들을 딕셔너리화 하여 result 리스트에 추가
        for n,r,u,p,c in zip(name_tags,rate_tags,url_list,price_list,count_reviews_list):
            result.append({
                "이름":n.text,
                "평점":r.text,
                "후기 개수" :c,
                "가격":p,
                "링크":u
            })
        for item in result:
            if item["이름"] not in result_list:
                result_list.append(item)

                
                
    #최저 가격 숙소 / 최고 평점 숙소 구하기            
    min_price=1000000
    name_of_min_price=""
    min_url=""
    
    highest_rate=0.00
    name_of_hr=""
    highest_url=""
    
    for item in result_list:
        price=item["가격"]
        price=price.replace("₩","")
        price=int(price.replace(",",""))

        if price<min_price:
            min_price=price
            name_of_min_price=item["이름"]
            min_url=item["링크"]
            
        rate=float(item["평점"])
        if rate>highest_rate:
            highest_rate=rate
            name_of_hr=item["이름"]
            highest_url=item["링크"]


    return result_list,"최저 가격 숙소 : %s (가격 : %d), (url : %s )" %(name_of_min_price,min_price,min_url),"최고 평점 숙소 : %s (평점 : %.2f), (url : %s)" %(name_of_hr,highest_rate,highest_url)

# %%
air=airbnb("서울","2020-08-16","2020-08-17",3)

# %%
air
# Out:
# ([{'이름': 'G-11 / Gangnam-Station / Private Room / Twin Beds',
#    '평점': '4.40',
#    '후기 개수': '15개',
#    '가격': '27,727',
#    '링크': 'https://www.airbnb.co.kr/rooms/38743673?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '푸통 한남 _201 (한남오거리/한남역 도보 3분)',
#    '평점': '4.86',
#    '후기 개수': '37개',
#    '가격': '26,910',
#    '링크': 'https://www.airbnb.co.kr/rooms/35855357?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '[여성 전용] 역삼역 그리고 고양이 두마리 (=ↀωↀ=)',
#    '평점': '4.84',
#    '후기 개수': '70개',
#    '가격': '49,678',
#    '링크': 'https://www.airbnb.co.kr/rooms/35526303?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '강남 역삼동 게스트하우스 싱글룸 #307',
#    '평점': '4.80',
#    '후기 개수': '59개',
#    '가격': '19,440',
#    '링크': 'https://www.airbnb.co.kr/rooms/42568735?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '크레토더블(7월~8월  14시 무료 체크아웃 연장)',
#    '평점': '4.32',
#    '후기 개수': '133개',
#    '가격': '71,250',
#    '링크': 'https://www.airbnb.co.kr/rooms/29467869?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '[Capsule Hotel#3] The Stay Simple, Central Gangnam',
#    '평점': '4.25',
#    '후기 개수': '8개',
#    '가격': '23,106',
#    '링크': 'https://www.airbnb.co.kr/rooms/19174078?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': 'Gangnam H Residence',
#    '평점': '4.49',
#    '후기 개수': '49개',
#    '가격': '26,965',
#    '링크': 'https://www.airbnb.co.kr/rooms/43795878?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '[여성전용 개인실] 신축 투룸 빌라 건대입구,구의역과 가까운 숙소',
#    '평점': '4.74',
#    '후기 개수': '31개',
#    '가격': '25,463',
#    '링크': 'https://www.airbnb.co.kr/rooms/44104117?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': 'NEW SALE:❤of Myeong-dong明洞- Double w/ private bath',
#    '평점': '4.14',
#    '후기 개수': '14개',
#    '가격': '39,280',
#    '링크': 'https://www.airbnb.co.kr/rooms/22850652?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': 'in stn!] Seolleung Rin’s house with Netflix',
#    '평점': '5.0',
#    '후기 개수': '7개',
#    '가격': '104,011',
#    '링크': 'https://www.airbnb.co.kr/rooms/39877611?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '[UHGRO #N23] Perfect house for group in Gangnam',
#    '평점': '4.87',
#    '후기 개수': '45개',
#    '가격': '57,765',
#    '링크': 'https://www.airbnb.co.kr/rooms/32250298?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '[Myeong-dong] Merlin Hotel Double / N-Tower View#3',
#    '평점': '4.59',
#    '후기 개수': '27개',
#    '가격': '36,970',
#    '링크': 'https://www.airbnb.co.kr/rooms/42937509?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '강남 펜트하우스 #Rooftop Room #개인화장실 #옥상테이블 #옥상텃밭',
#    '평점': '4.80',
#    '후기 개수': '10개',
#    '가격': '46,212',
#    '링크': 'https://www.airbnb.co.kr/rooms/29983074?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': 'Woman&family Private[2A] ★OPEN!!!!★hanyang/왕십리',
#    '평점': '4.66',
#    '후기 개수': '85개',
#    '가격': '26,456',
#    '링크': 'https://www.airbnb.co.kr/rooms/38953454?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '강남역 조용하고 가격좋은 호텔',
#    '평점': '4.67',
#    '후기 개수': '9개',
#    '가격': '53,143',
#    '링크': 'https://www.airbnb.co.kr/rooms/44235406?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '[Sinsa station] 1min walk Modern private room',
#    '평점': '4.55',
#    '후기 개수': '129개',
#    '가격': '67,007',
#    '링크': 'https://www.airbnb.co.kr/rooms/43823623?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': 'Central Rooftop Double Room @Gangnam by Grammos',
#    '평점': '4.70',
#    '후기 개수': '105개',
#    '가격': '104,000',
#    '링크': 'https://www.airbnb.co.kr/rooms/31580253?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d'},
#   {'이름': '<소독.방역처리>명동거리/옥상가든/신축/풀옵션/지하철역도보',
#    '평점': '4.83',
#    '후기 개수': '18개',
#    '가격': '71,885',
#    '링크': 'https://www.airbnb.co.kr/rooms/40765276?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '*Open* Residence.Muha R1 (Hangangjin, Hannam)',
#    '평점': '4.88',
#    '후기 개수': '8개',
#    '가격': '48,363',
#    '링크': 'https://www.airbnb.co.kr/rooms/43252218?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': 'G-21 / Gangnam-Station / Private Room / Twin Beds',
#    '평점': '4.68',
#    '후기 개수': '37개',
#    '가격': '24,954',
#    '링크': 'https://www.airbnb.co.kr/rooms/35356490?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '푸통 한남 _203 (한남오거리/한남역 도보 3분)',
#    '평점': '4.78',
#    '후기 개수': '36개',
#    '가격': '26,910',
#    '링크': 'https://www.airbnb.co.kr/rooms/35856657?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '[Capsule Hotel#2] The Stay Simple, Central Gangnam',
#    '평점': '4.22',
#    '후기 개수': '100개',
#    '가격': '23,106',
#    '링크': 'https://www.airbnb.co.kr/rooms/19174020?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': 'Estudio Nuevo: MODU#2',
#    '평점': '4.84',
#    '후기 개수': '61개',
#    '가격': '78,560',
#    '링크': 'https://www.airbnb.co.kr/rooms/35019351?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': 'SUN CITY private room',
#    '평점': '4.58',
#    '후기 개수': '19개',
#    '가격': '40,435',
#    '링크': 'https://www.airbnb.co.kr/rooms/16728635?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '진진 스튜디오 (한남동 현대라이브러리 뒷편)',
#    '평점': '4.0',
#    '후기 개수': '17개',
#    '가격': '80,870',
#    '링크': 'https://www.airbnb.co.kr/rooms/41674598?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '[SALE]Jamsil Seoulㅁ5min subway, lake&Lotte tower',
#    '평점': '4.64',
#    '후기 개수': '58개',
#    '가격': '42,274',
#    '링크': 'https://www.airbnb.co.kr/rooms/32702221?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '#3/강남역 1번 3분 거리/쾌적하고 넓은 원룸/전문 청소업체 고용/파티허용/청소비X',
#    '평점': '4.52',
#    '후기 개수': '29개',
#    '가격': '72,783',
#    '링크': 'https://www.airbnb.co.kr/rooms/40481127?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '쾌적하고 조용한 가성비 좋은 원룸텔 #개별욕실 #복도방3',
#    '평점': '4.50',
#    '후기 개수': '40개',
#    '가격': '17,330',
#    '링크': 'https://www.airbnb.co.kr/rooms/44198707?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '(WOMEN ROOM)*Best for Solo*Capsule room in Seoul',
#    '평점': '4.89',
#    '후기 개수': '150개',
#    '가격': '17,100',
#    '링크': 'https://www.airbnb.co.kr/rooms/29593132?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': 'A Super Cozy Place With Romantic View in Jamsil',
#    '평점': '4.58',
#    '후기 개수': '99개',
#    '가격': '114,375',
#    '링크': 'https://www.airbnb.co.kr/rooms/30897377?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '#청소비추가없음 #매일소독 #청소전문업체이용 #복층 , Gangnam St(5min)#3',
#    '평점': '4.55',
#    '후기 개수': '38개',
#    '가격': '127,082',
#    '링크': 'https://www.airbnb.co.kr/rooms/40161746?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '신논현 먹자골목에 위치한 프라이빗 스튜디오',
#    '평점': '4.91',
#    '후기 개수': '154개',
#    '가격': '70,473',
#    '링크': 'https://www.airbnb.co.kr/rooms/34071274?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '韓国ソウル close to Jamsil Rotte Mall in seoul',
#    '평점': '4.75',
#    '후기 개수': '28개',
#    '가격': '16,174',
#    '링크': 'https://www.airbnb.co.kr/rooms/43427319?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': 'Sunshine * Studio [REOPEN]',
#    '평점': '4.0',
#    '후기 개수': '8개',
#    '가격': '73,939',
#    '링크': 'https://www.airbnb.co.kr/rooms/21347041?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '빈방 7호점 _Itaewon station in 6mn',
#    '평점': '4.69',
#    '후기 개수': '42개',
#    '가격': '95,890',
#    '링크': 'https://www.airbnb.co.kr/rooms/40864752?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c'},
#   {'이름': '푸통 한남 _204 (한남오거리/한남역 도보 3분)',
#    '평점': '4.63',
#    '후기 개수': '41개',
#    '가격': '26,910',
#    '링크': 'https://www.airbnb.co.kr/rooms/35886709?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': 'Estudio Nuevo: MODU#2',
#    '평점': '4.84',
#    '후기 개수': '61개',
#    '가격': '78,560',
#    '링크': 'https://www.airbnb.co.kr/rooms/35019351?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': '#3/강남역 1번 3분 거리/쾌적하고 넓은 원룸/전문 청소업체 고용/파티허용/청소비X',
#    '평점': '4.52',
#    '후기 개수': '29개',
#    '가격': '72,783',
#    '링크': 'https://www.airbnb.co.kr/rooms/40481127?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': '[Female Only 女性专用] 역삼역 5분,가성비 최고 yeoksam sta. 5min',
#    '평점': '4.50',
#    '후기 개수': '20개',
#    '가격': '17,330',
#    '링크': 'https://www.airbnb.co.kr/rooms/33792214?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': 'seoul mansion',
#    '평점': '4.71',
#    '후기 개수': '59개',
#    '가격': '27,727',
#    '링크': 'https://www.airbnb.co.kr/rooms/44514021?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': '[Star Stay] #신논현역2분#뉴욕모던#브루클린스튜디오#무료주차#강남맛집메인상권',
#    '평점': '4.12',
#    '후기 개수': '136개',
#    '가격': '91,268',
#    '링크': 'https://www.airbnb.co.kr/rooms/42048207?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': 'Da Da House',
#    '평점': '4.69',
#    '후기 개수': '42개',
#    '가격': '75,095',
#    '링크': 'https://www.airbnb.co.kr/rooms/43948645?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': '[Capsule Hotel] The Stay Simple#Private in Gangnam',
#    '평점': '4.61',
#    '후기 개수': '58개',
#    '가격': '23,106',
#    '링크': 'https://www.airbnb.co.kr/rooms/19184456?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': 'Girls Generation Hostel only for ladies 1',
#    '평점': '3.73',
#    '후기 개수': '15개',
#    '가격': '19,640',
#    '링크': 'https://www.airbnb.co.kr/rooms/44496487?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': 'A pleasant stay in Jamsil off the 9 Station Subway',
#    '평점': '4.89',
#    '후기 개수': '150개',
#    '가격': '63,541',
#    '링크': 'https://www.airbnb.co.kr/rooms/34765364?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': 'Gangnam/Seolleung Quiet room-강남/선릉/대치동/역삼',
#    '평점': '4.75',
#    '후기 개수': '28개',
#    '가격': '86,647',
#    '링크': 'https://www.airbnb.co.kr/rooms/20155935?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': 'Gangnam Moxen House',
#    '평점': '4.38',
#    '후기 개수': '26개',
#    '가격': '23,106',
#    '링크': 'https://www.airbnb.co.kr/rooms/33672680?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': 'A Super Cozy Place With Romantic View in Jamsil',
#    '평점': '4.50',
#    '후기 개수': '148개',
#    '가격': '114,375',
#    '링크': 'https://www.airbnb.co.kr/rooms/30897377?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': '빈방 7호점 _Itaewon station in 6mn',
#    '평점': '4.96',
#    '후기 개수': '49개',
#    '가격': '95,890',
#    '링크': 'https://www.airbnb.co.kr/rooms/40864752?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': 'Single House_Shared toilet room2',
#    '평점': '4.52',
#    '후기 개수': '42개',
#    '가격': '18,485',
#    '링크': 'https://www.airbnb.co.kr/rooms/33942894?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'},
#   {'이름': 'JB1★Cozy Flat Sindang Stn Near Dongdaemun',
#    '평점': '4.83',
#    '후기 개수': '64개',
#    '가격': '71,628',
#    '링크': 'https://www.airbnb.co.kr/rooms/44252456?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=2f974f66-0d17-4b3d-9196-d17cadf458e1'}],
#  '최저 가격 숙소 : 韓国ソウル close to Jamsil Rotte Mall in seoul (가격 : 16174), (url : https://www.airbnb.co.kr/rooms/43427319?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=4e5fcf09-b136-4789-aa01-2b3261e9aa2c )',
#  '최고 평점 숙소 : in stn!] Seolleung Rin’s house with Netflix (평점 : 5.00), (url : https://www.airbnb.co.kr/rooms/39877611?location=%EC%84%9C%EC%9A%B8&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=c920b802-f01d-4edb-bbdc-d6c7c4b6aa1d)')

# %%
dt=pd.DataFrame(air[0])

# %%
dt.to_excel("airbnb_crawling.xlsx")

# %%
class Hotel:
    def __init__ (self,place,checkin,checkout,pages):
        self.place=place
        self.checkin=checkin
        self.checkout=checkout
        self.pages=pages
        
    #airbnb 크롤링
    def airbnb(self):  #place = 장소, checkin = 체크인 날짜, checkout :체크아웃 날짜, pages=검색하고자 하는 페이지 수
    
    
        result_list=[]  #크롤링 최종 결과를 담을 리스트

        #에어비앤비는 offset이 20단위로 페이지가 변화 ex)offset 0 : 1페이지 , offset 1~20: 2페이지 
        for page in range(1,self.pages+1): #입력받은 페이지 수만큼 모두 크롤링 하기 위해
            if page==1:  #page가 1이면 offset=0
                offset=0
            else:
                offset=page*20  #1보다 크면 page*20


            #리퀘스트할 url과 파라미터 설정
            base_url="https://www.airbnb.co.kr/s/%s/homes" %self.place
            params={'query': self.place,
             'federated_search_session_id': 'e296e38b-6ec1-4296-9a81-f762cfb2c92a',
             'source': 'structured_search_input_header',
             'search_type': 'pagination',
             'tab_id': 'home_tab',
             'checkin': self.checkin,
             'refinement_paths[]': '/homes',
             'checkout': self.checkout,
             'section_offset': '2',
             'items_offset': offset}

            resp=requests.get(base_url,params=params)
            soup=bs(resp.text)
            item_tags=soup.select("#FMP-target > div > div > div > div")
            len(item_tags[0])


            #해당 숙소에 대한 상세페이지 url을 가져옴
            a_tags=item_tags[0].find_all("a")
            url_list=[]
            for i in a_tags:
                url_list.append("https://www.airbnb.co.kr%s" %i.get("href"))


            #숙소들의 가격정보를 가져옴
            price_tags=item_tags[0].find_all("span", class_="_1p7iugi")
            price_list=[]
            for i in price_tags:
                try:
                    price=i.text.split(":")[2]
                except:
                    price=i.text.split(":")[1]
                price=price.replace("₩","")
                price=price.replace(",","")
                price_list.append(float(price))
    
            #숙소들의 리뷰 개수를 가져옴
            count_reviews=item_tags[0].find_all("span",class_="_krjbj")
            count_reviews
            count_reviews_list=[]
            for i in count_reviews:
                if "후기" in str(i):
                    count_reviews_list.append(i.text.split(" ")[1].replace("개",""))

            #숙소들의 이름과 평점을 가져옴
            name_tags=item_tags[0].find_all("div",class_="_1c2n35az")
            rate_tags=item_tags[0].find_all("span",class_="_10fy1f8")

            result=[]

            #앞에서 추출한 정보들을 딕셔너리화 하여 result 리스트에 추가
            for n,r,p,c in zip(name_tags,rate_tags,price_list,count_reviews_list):
                result.append({
                    "이름":n.text,
                    "평점":float(r.text),
                    "리뷰 개수" :int(c),
                    "가격":int(p),
                    "사이트":"AirBnb"
                })
            for item in result:
                if item["이름"] not in result_list:
                    result_list.append(item)



        #최저 가격 숙소 / 최고 평점 숙소 구하기            
        min_price=1000000
        name_of_min_price=""
        min_url=""

        highest_rate=0.00
        name_of_hr=""
        highest_url=""

        for item in result_list:
            price=item["가격"]
#             price=price.replace("₩","")
#             price=float(price.replace(",",""))

            if price<min_price:
                min_price=price
                name_of_min_price=item["이름"]
#                 min_url=item["링크"]

            rate=float(item["평점"])
            if rate>highest_rate:
                highest_rate=rate
                name_of_hr=item["이름"]
#                 highest_url=item["링크"]


        return result_list,"최저 가격 숙소 : %s (가격 : %d), (url : %s )" %(name_of_min_price,min_price,min_url),"최고 평점 숙소 : %s (평점 : %.2f), (url : %s)" %(name_of_hr,highest_rate,highest_url)

    
    def hotels(self):

        result_list=[]
        for page in range(1,self.pages+1):

            base_url='https://kr.hotels.com/search/listings.json'
            params={
                #'pg-offset':page,
                #'distination-id':'1644457', 
                'q-check-out':self.checkout,
                'q-destination':self.place,
                'q-check-out':self.checkout,
                'q-rooms':1,
                'q-room-0-adults':1,
                'q-room-0-children':0,
                'pg':1,
                #'start-index':1,
                'pn':page,
                #'resolved-location':'REGION:1644457:UNKNOWN:UNKNOWN'
            }

            headers={
                'content-type': 'application/javascript',
                'x-requested-with': 'XMLHttpRequest',
                #'referer':'https://kr.hotels.com/search.do?resolved-location=REGION%3A1644457%3AUNKNOWN%3AUNKNOWN&destination-id=1644457&q-destination={0}&q-check-in=2020-08-16&q-check-out=2020-08-17&q-rooms=1&q-room-0-adults=1&q-room-0-children=0'.format(urllib.parse.quote('제주도')),
                'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36',
                'cookie': "asc=1; homepage_search_data=7KCc7KO864-ELCDsoJzso7zsi5wsIO2VnOq1rQ..%2F%2F2020%2F08%2F16%2F%2F2020%2F08%2F17%2F%2F1%2F%2Fyyyy%2FMM%2Fdd%2F%2F1644457%2F%2F; guid=8c8ca612-b270-42cb-95aa-6232c2538458; user=QSprb19LUnxIQ09NX0tS; dr=AAA~1596523818~5C85BBDD535AE5EBF43E87FBF3ED905266EB65950AFBFD78AC0671363A77CA79; akacd_pr_20=1601707820~rv=31~id=44ca8f82368ff8df2ac1cef34c3ccc77; bm_sz=91F45291ECCBD9CF669AE98B49CA6C7D~YAAQa3pGaFBIOoBzAQAALzY8uAjOZf4bEil+pJ9j7T4xHGo5L0We9RrvFkah4Ntqo/cwcLTTJE/iBUXVgkfqE0iJKW9BFb7MP7TecuUec4RqjpNsP2kaEjHxE5mKNYefWc2HoK06cqN5xm/nP7KJBfW4ANgO3yTiCM6bebnDHYkGER21/OCeV4M8NejdwiHs; _ga=GA1.2.20859871.1596523819; _gid=GA1.2.1549673115.1596523819; s_ecid=MCMID%7C78976063976117546201547030336521815933; AMCVS_C00802BE5330A8350A490D4C%40AdobeOrg=1; mvthistory=eJxNj0kKQjEQRG8U0lN62LoRRAQv4PrfwcPb%2Bd2Kq7w8qorEbawxx0EQQJaEgap5zmCXsemwgAl8ugQZuKUHQAZOyUjDva3MqidYRWmzt4RZoGoFhr1iCpXXAOd1Spzm3xEko2IIFMQBFUZZNY5i0uBdX8QVg7xo2XFg0O%2BTANIgXOucvKilzupTMHJXeGGBQA%2FCZv1jK6bN3mHqF%2Be%2B27n%2Fvl4e99ft%2BQErFlFN; AMCV_C00802BE5330A8350A490D4C%40AdobeOrg=-1330315163%7CMCIDTS%7C18479%7CMCMID%7C78976063976117546201547030336521815933%7CMCAID%7CNONE%7CMCOPTOUT-1596531019s%7CNONE%7CMCAAMLH-1597128619%7C11%7CMCAAMB-1597128619%7Cj8Odv6LonN4r3an7LhD3WZrU1bUpAkFkkiY1ncBR96t2PTI; s_cc=true; _abck=2ED1A02051B8DEB245303D2079BFA297~0~~-1~-1~-1; _gcl_au=1.1.160751177.1596523820; _fbp=fb.1.1596523820167.896421725; 0e16e784-167b-49ee-b1ac-0ff7866eb4fbfaktorId=5cac8980-8e5b-4cc8-82d6-c10efc3d3428; lastConsentChange=1596523820269; 0e16e784-167b-49ee-b1ac-0ff7866eb4fbeuconsent=BO3mjO6O3mjO6ADABAENDV-AAAAx6ATgAUABoAEAAKwAXABkAEAAMgAaQBEAEUAI4ATAAngBbAEEAJAATgBCACpAHVARqA; 0e16e784-167b-49ee-b1ac-0ff7866eb4fbcconsent=BO3mjO6O3mjO6ADABAENA7AAAAAOWAAA; 0e16e784-167b-49ee-b1ac-0ff7866eb4fbfaktorChecksum=-1176279445; __gads=ID=0b734ce775df8ba2-222c1fd2c6c2005b:T=1596523822:S=ALNI_MZhdUG_e5KVdQLyxGd-QTgPh34YZg; xdid=0e1a2a2a-35f6-4831-a4f6-f3389ef1ca7a|1596523822|kr.hotels.com; xdidp=0e1a2a2a-35f6-4831-a4f6-f3389ef1ca7a|1596523822|kr.hotels.com; s_sq=%5B%5BB%5D%5D; visitId=edbcaa2e-4968-4009-ac85-383907b77d5f; SESSID=kmF9C5mRd1F3cSUDGpr_gCaDoZ.sa-6f74c7cf76-x4jn8; Session_Pageviews=6; _uetsid=c6e7370525e12b88d62d48ad3703a7c3; _uetvid=3363ca2720f5a4cef91d6a35a5ae68ab",
                #'pragma': 'no-cache',
                #'cache-control': 'no-cache',
                #'accept': 'application/json, text/javascript, */*; q=0.01',
                #'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
                #'accept-encoding': 'gzip, deflate, br'

            #     'cookie': 'channel=DC; 30dlt=seo.hcom.kr.b2.search.naver.com; guid=70b194a6-7d06-4407-813d-439ddc81e8b1; user=QSprb19LUnxIQ09NX0tS; akacd_pr_20=1601370854~rv=10~id=56b99db0bffa807a7ae68b57c1f84d62; _ga=GA1.2.262126391.1596186854; s_ecid=MCMID%7C18020916849438730392200037473831731739; _fbp=fb.1.1596186855014.1096204561; _gcl_au=1.1.2093965117.1596186855; __gads=ID=28a1f36c47d1b899:T=1596186855:S=ALNI_MbMfgFuOVpeHde-Lxvoqy6try5X3w; xdid=03a4919c-5c4e-476b-9704-1db0fd86a8cf|1596186857|kr.hotels.com; xdidp=23fa12ed-bf86-42d0-b153-3665d6e271eb|1596186754|expedia.co.kr; lastConsentChange=1596186857180; mvthistory=eJxNj0luRCEMRG%2BEKA942PampSiKlAtk%2Fe%2BQwwe%2B3a2seDyVyxA%2B1pjjYiTYN1GS2T5nSug4dHliQm63QQcdGQnswC2FeES01VnjG7yifDhaYhaYeYFTt7ih8pYIWbek6fEqIXYuRpISDVSYdFU5qWtD9PhiqRj2xcqOi5LfnwS0QaXaZfPiljZrnlNIeoQnqsdSZFFJRZfjsP1jL%2BbD0WHu1%2B9d4feu3%2Bfj6%2FPn4%2FsPA1NT2Q%3D%3D; bm_sz=9BD21E821845D51FA0D9B135BB256B3A~YAAQDXpGaMvdmYZzAQAA7BL3sgjXMidVKi2JZezEhByPD+UlXFPyGWEuydcxo7jaG5deLqOuRULrEn/lhgOo6iEtj0Wad9xJ0uolA4BJwtwL18+2xpptdBd8jS3LfCLmEC2uX/WB2NnK4m4x4mzrUm7mHQGUykHOubX9A0cqY4zyEdtY0AH0PZ63K2zYl6Mi; asc=1; dr=AAA~1596435404~4AF6F0445D3489A1E092F641066F96B93D40B40DDD943022EE1E98D4913A7C2F; _gid=GA1.2.1546820872.1596435403; AMCVS_C00802BE5330A8350A490D4C%40AdobeOrg=1; s_cc=true; _abck=0D541D156BC09BE7D94D3AADD67548B2~0~~-1~-1~-1; homepage_search_data=7KCc7KO864-ELCDsoJzso7zsi5wsIO2VnOq1rQ..%2F%2F2020%2F08%2F16%2F%2F2020%2F08%2F17%2F%2F1%2F%2Fyyyy%2FMM%2Fdd%2F%2F1644457%2F%2F; visitId=9c2e2fae-5554-4ea6-a40b-89f3d70f6305; SESSID=d1zQ1OkaL9VJyQvfYjWcg2o8sR.sa-665cf686c4-7q8g6; s_sq=%5B%5BB%5D%5D; aws=1; _gat=1; AMCV_C00802BE5330A8350A490D4C%40AdobeOrg=-1330315163%7CMCIDTS%7C18478%7CMCMID%7C18020916849438730392200037473831731739%7CMCAAMLH-1596791653%7C11%7CMCAAMB-1597047604%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1596450004s%7CNONE%7CMCAID%7CNONE; Session_Pageviews=14; _uetsid=f42780afb3dcaf6da3acf7261a71a6e4; _uetvid=26e44a5e73df2819b24f5fccdadd9add'
            }

            s = requests.Sessionㅉ
            resp=s.get(base_url,params=params,headers=headers)
            items=json.loads(resp.text)


            results=items['data']['body']['searchResults']['results']


            hotels_list=[]

            for i in range(len(results)):
                hotels_names=items['data']['body']['searchResults']['results'][i]['name']
                if ('guestReviews' in items['data']['body']['searchResults']['results'][i])==False:
                    hotels_stars=0
                else:
                    hotels_stars=items['data']['body']['searchResults']['results'][i]['guestReviews']['rating']
                    hotels_reviews=items['data']['body']['searchResults']['results'][i]['guestReviews']['total']
                if ('soldOut' in items['data']['body']['searchResults']['results'][i])==False:
                    hotels_prices=items['data']['body']['searchResults']['results'][i]['ratePlan']['price']['exactCurrent']
                else:
                    hotels_prices='SoldOut'

                hotels_list.append({
                    '이름': hotels_names,
                    '평점': float(hotels_stars)/2,
                    '리뷰 개수': int(hotels_reviews),
                    '가격': int(hotels_prices),
                    "사이트":"호텔스닷컴"})
                    
            for hotel in hotels_list:
                if hotel not in result_list:
                    result_list.append(hotel)

        return result_list

    
#3

    def yanolja(self):
        result_list=[]
        for page in range(1,self.pages+1):
            base_url = "https://www.yanolja.com/api/v1/contents/search"
            params = {
                'capacityAdult':1,
                'capacityChild':0,
                'page':page,
                'limit':20,
                'keyword':self.place,
                'checkinDate':self.checkin,
                'checkoutDate':self.checkout,
                'searchKeyword':self.place,
                'advert': 'KEYWORD',
                'searchType': 'all',
                'all': 1,
                'sort': 100,
                'themes': None,
                'lat': '37.50681',
                'lng': '127.06624',
                'capacityChildAges': None  
            }

            headers = {
                'Referer' : 'https://www.yanolja.com/search/{0}?placeListType=search&keyword={0}'.format(urllib.parse.quote(self.place)),
                'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36',
                'X-Requested-With': 'XMLHttpRequest',
                'Accept': 'application/json, text/plain, */*',
                'Accept-Encoding': 'gzip, deflate, br',
                'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
            #     'Cookie': 'ACEUCI=1; %2Fsearch%2F%EC%A0%9C%EC%A3%BC%EB%8F%84%2Fkeyword-all={%22keyword%22:%22%EC%A0%9C%EC%A3%BC%EB%8F%84%22%2C%22searchKeyword%22:%22%EC%A0%9C%EC%A3%BC%EB%8F%84%22%2C%22checkinDate%22:%222020-08-16%22%2C%22checkoutDate%22:%222020-08-17%22%2C%22capacityAdult%22:1%2C%22capacityChild%22:0%2C%22capacityChildAges%22:%22%22}; cgntId=ap-northeast-2%3A2b47caae-3694-44f0-9d2b-43c98b30c098; yanolja_sid=s%3A0K-pijLPMujuW6NI5cJVcGOYBO2FXY0h.ZwiC623ThkJsrpFM9m7MiLj%2F8qYFHr3272Xla0K8NCk; SavedFiltersKey=/search/%EC%A0%9C%EC%A3%BC%EB%8F%84/keyword-all; ACEUACS=1596521299174217533; ACEFCID=UID-5F28FB542D0B4D05779333B5; _fbp=fb.1.1596521300441.1991528559; _ga=GA1.2.1408952294.1596521300; _gid=GA1.2.788840749.1596521300; location={%22latitude%22:%2237.50681%22%2C%22longitude%22:%22127.06624%22%2C%22address%22:%22%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EA%B0%95%EB%82%A8%EA%B5%AC%20%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%2042%22%2C%22addressShort%22:%22%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EA%B0%95%EB%82%A8%EA%B5%AC%20%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%22%2C%22addressOnlyRoad%22:%22%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%22}; wcs_bt=ae93a192ec48a4:1596521393; AWSALB=zm/Jfq0CVy83/Q/bcMcY2ADivgyVdh6KNQc6bG1tPs9SA7T5733p2wvOClRpxNMSodWkruizJEGIcJbThOG1sBYm+WURo+8cqojOGppWN4ykkwQMNbQuiwexg5Nx; AWSALBCORS=zm/Jfq0CVy83/Q/bcMcY2ADivgyVdh6KNQc6bG1tPs9SA7T5733p2wvOClRpxNMSodWkruizJEGIcJbThOG1sBYm+WURo+8cqojOGppWN4ykkwQMNbQuiwexg5Nx'
            }

            ## 호텔리스트가 홈페이지랑 다르게 나옴 -> 쿠키가 계속 갱신되는 것을 방지하기 위해 -> 처음 홈페이지에 들어가자마자의 쿠키를 저장해놓는다.
            s = requests.Session()
            s.get("https://www.yanolja.com/search/{0}?placeListType=search&keyword={0}".format(self.place))
            resp = s.get(base_url, params=params, headers=headers)
            # resp = requests.get(base_url, params = params, headers=headers)


            item_li = json.loads(resp.text)

            item_list = []
            #name_list = []
            #score_list = []
            #price_list = []


            for i in range(20):
                
                

                # 호텔 이름

                name = item_li['motels']['lists'][i]['name']
                #name_list.append(name)
            #print(name_list)



                # 호텔 점수

                score = item_li['motels']['lists'][i]['reviewScore']
                #score_list.append(score)
            #print(score_list)



                # 리뷰 개수

                count = item_li['motels']['lists'][i]['reviewCounts']
                #count_list.append(count)
            #print(count_list)



                # 호텔 가격 = > 예약마감이면 예약마감이 뜬다.

                if len(item_li['motels']['lists'][i]['displayPrices']) == 1:
                    if item_li['motels']['lists'][i]['displayPrices'][0]['priceNote'] == '예약마감':
                        continue
                        #price_list.append(price)

                    else:
                        price = item_li['motels']['lists'][i]['displayPrices'][0]['rawDiscountPrice']
                        #price_list.append(price)

                elif len(item_li['motels']['lists'][i]['displayPrices']) >= 2:
                    for j in range(2):
                        if item_li['motels']['lists'][i]['displayPrices'][j]['badgeText'] == '숙박특가':
                            if item_li['motels']['lists'][i]['displayPrices'][j]['priceNote'] == '예약마감':
                                continue
                                #price_list.append(price)

                            else:
                                price = item_li['motels']['lists'][i]['displayPrices'][j]['rawDiscountPrice']
                                #price_list.append(price)
            #print(price_list)



                item_list.append({'이름' : name, 
                                  '평점' : float(score),
                                  '리뷰 개수' : int(count),
                                '가격': price,
                                "사이트":"야놀자"})
                
                
            result_list.extend(item_list)    
        return result_list    

    
    
#4 

    def booking(self):
        base_url='https://www.booking.com/searchresults.ko.html'
        total=[]
        for i in range(self.pages):
            params={
            'top_ufis':1,
            'rows':25,
            'group_adults':1,
            'group_children':0,
            'label_click':'undef',
            'checkin_month':self.checkin.split("-")[1],
            'checkin_monthday':self.checkin.split("-")[2],
            'checkin_year':self.checkin.split("-")[0],
            'checkout_month':self.checkout.split("-")[1],
            'checkout_monthday':self.checkout.split("-")[2],
            'checkout_year':self.checkout.split("-")[0],
            'no_rooms':1,
            #'raw_dest_type':'region',
            'offset':25*i,   
            'sb_price_type': 'total',
            'ss': self.place,
            #'src_elem': 'sb', 
            #'ss_all':0,
            #'ssb': 'empty',
            #'dest_type': 'region',
            #'search_pageview_id': 'b78a37b8196a0080'
            'search_selected':1
            }
            headers = {
                'Referer': 'https://www.booking.com/searchresults.ko.html',
                'Cookie': 'cors_js=1; _gcl_au=1.1.1758010469.1596413772; bs=%7B%22sr_country_or_region_page%22%3A%22region%22%7D; _ga=GA1.2.882061434.1596413773; _gid=GA1.2.1846610763.1596413773; BJS=-; zz_cook_tms_seg1=1; zz_cook_tms_ep=1; zz_cook_tms_seg3=7; _scid=dff99b5d-2e14-4af2-9550-58237e3d9d4c; _pxvid=8ac1c871-d51e-11ea-b163-0242ac120009; _sctr=1|1596380400000; _pin_unauth=dWlkPU9UazVabVF4T1RRdE56bGhPQzAwTUdabUxXSm1ORFF0WldRMVptVmpNemRrWXpVdw; has_preloaded=1; zz_cook_tms_hlist=3317637; g_state={"i_p":1596531334237,"i_l":2}; utag_main=v_id:0173b1ad0651001df4a85a0a77f203073044706b00bd0$_sn:1$_ss:0$_st:1596448493168$4split:2$4split2:1$ses_id:1596413773394%3Bexp-session$_pn:16%3Bexp-session; _uetsid=f2d8e4c9c62246a0bed0af7e885f8c9f; _uetvid=269cfd473b2529680b9b538f1b46fbc1; bkng=11UmFuZG9tSVYkc2RlIyh9Yaa29%2F3xUOLbXpFeYC4TUhBdXo35xAS%2BPyXteEmAF00C7ntv3OHZGFN5Omw3tnwU%2F3rlk1nbz%2BONusrZE%2BcQgZLBk0JeBSBtWgSf%2BJ%2BC2ShbUfWTKv6cwfj%2FUbmattwzhSpTIYyiyIWa7e5d6rxwuVVQqabr7YAgMkH%2F%2Fu6fNsyuyQoTASDGyEw%3D; _px3=534b016a13eceb8dfd91bad5c3807ed4049eeef67f96ffa26e4b9b0710069380:RhcCPVe8GBdA9jMG9PvURiL0ylPlLetN980mHJcuwmC2w9omcccJP2dnTAIXjLyb5eVJcGGTsFBxUVGdCNCg6g==:1000:sGlUhQDbcD++cAinRcf8FQIrgXsopgDXZYkK7uRiQhuAUhE1XXniOrLt6s/Gb1GMVWTdokUn2mREYh+JnCAJ6PpWZsrVHgWYSaF8wEucBT9rs5PjjXKHUrT7Y6DZV/P832v9mal2qz9asNi/uf7Gt9o/kTvyVoqN90YhP8ivD2M=; _pxde=8e07b07f8b1c1d5d950a0e87a21708a96b04456fe969788c88d7c52548705a1e:eyJ0aW1lc3RhbXAiOjE1OTY0NDY3NjkxMjMsImZfa2IiOjAsImlwY19pZCI6W119; lastSeen=0',
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'    }
            resp=requests.get(base_url,params=params, headers=headers)
            soup=bs(resp.text)

        #     hotellist_inner=soup.find('div',id='hotellist_inner')
        #     hotels=hotellist_inner.find_all('div', class_='sr_item')
            hotels = soup.find_all('div', class_='sr_item')

            hotel_list=[]
            for hotel in hotels:        
                names=hotel.find('span',class_='sr-hotel__name')
                name=names.text#호텔이름
                reviews=hotel.find('div',class_='bui-review-score__badge')
                if reviews:
                    review=reviews.text
                else:
                    review= None
                prices=hotel.find('div',class_='bui-price-display__value')
                price=prices.text

                counts=hotel.find('div',class_='bui-review-score__text')
                if counts:
                    count = counts.text
                else:
                    count = 0
                hotel_list.append({
                    '이름':name,
                    '평점':review,
                    '리뷰 개수':count,
                    '가격':price,
                    "사이트":"부킹 닷컴"
                })
            total.extend(hotel_list)
         #데이터 잔처리,중복제거   
        for i in total:
            try:
                i['이름']=i['이름'].replace("\n","").strip()
                if i['평점']!=None:
                    i['평점']=i['평점'].strip()
                    i['평점']=float(i['평점'])/2
                i['가격']=i['가격'].replace("\n","").strip()
                i['가격']=i['가격'].replace("₩","").strip()
                if i['리뷰 개수']!=0:
                    i['리뷰 개수']=i['리뷰 개수'].strip()
                    a=i['리뷰 개수'].index('개')
                    count_str = i['리뷰 개수'][0:a]
                    count_str = count_str.replace(',', '')
                    i['리뷰 개수']=int(count_str)
                i['가격']=i['가격'].replace(',','')
                i['가격']=int(i['가격'])
            except Exception as e:
                print(i)
                print('---'*10)
                raise e
            #print(i)
        result_list=list({s['이름']:s for s in total}.values()) 
        return result_list
    
    
    
    
    def searched_hotels(self):
        df1=pd.DataFrame(self.airbnb()[0])
        df2=pd.DataFrame(self.hotels())
        df3=pd.DataFrame(self.yanolja())
        df4=pd.DataFrame(self.booking())
        
        result=df1.append([df2,df3,df4],ignore_index=True)
        result= result[result["가격"] != "예약 마감"]
        result["가격"].astype("int")
        result.drop_duplicates(inplace=True)
        
        min_price=result.loc[result["가격"].idxmin()]
        
        return result, min_price
    
    
#     def min_price(self):
#         return self.to_dataframe().loc[self.to_dataframe()["가격"].idxmin

# %%
search_hotel=Hotel("서울","2020-08-16","2020-08-17",3)

# %%
result=search_hotel.searched_hotels()
# Out:
# C:\Users\D.O\anaconda3\envs\study1\lib\site-packages\bs4\__init__.py:177: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 194 of the file C:\Users\D.O\anaconda3\envs\study1\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   warnings.warn(self.NO_PARSER_SPECIFIED_WARNING % dict(
# C:\Users\D.O\anaconda3\envs\study1\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
hotels_df=result[0]
hotels_df
# Out:
#                                                     이름    평점  리뷰 개수      가격  \
# 0    G-21 / Gangnam-Station / Private Room / Twin Beds  4.68     37   24954
# 1      [UHGRO #N23] Perfect house for group in Gangnam  4.14     14   56032
# 2                      [여성 전용] 역삼역 그리고 고양이 두마리 (=ↀωↀ=)  4.84     70   49678
# 3                         크레토더블(7월~8월  14시 무료 체크아웃 연장)  4.80     59   71250
# 4       in stn!] Seolleung Rin’s house with Netflix  4.74     31  103211
# ..                                                 ...   ...    ...     ...
# 206                                          호텔 피제이 명동  4.20    622   93660
# 207                                           아리랑힐 동대문  4.35   1434   96000
# 208                                            나인트리 호텔  4.35    898   46333
# 209                                         더 파크 호텔 서울  4.40    498   85050
# 210                                         스탠포드 호텔 서울  4.05    231   99000
#
#         사이트
# 0    AirBnb
# 1    AirBnb
# 2    AirBnb
# 3    AirBnb
# 4    AirBnb
# ..      ...
# 206   부킹 닷컴
# 207   부킹 닷컴
# 208   부킹 닷컴
# 209   부킹 닷컴
# 210   부킹 닷컴
#
# [211 rows x 5 columns]

# %%
hotels_df.to_csv("hotels_list.csv",encoding="utf-8-sig")

# %%
min_price=result[1]
min_price.to_frame()
# Out:
#            112
# 이름     서울숲 스테이
# 평점         4.9
# 리뷰 개수       33
# 가격       12000
# 사이트        야놀자

# %%
sns.distplot(hotels_df["가격"])

# %%
search_hotel1=Hotel("부산","2020-08-18","2020-08-19",1)

# %%
a=search_hotel1.booking()

# %%
a
# Out:
# [{'이름': '김치 해운대 게스트하우스', '평점': 4.2, '리뷰 개수': 825, '가격': 9000, '사이트': '부킹 닷컴'},
#  {'이름': '힐튼부산', '평점': 4.25, '리뷰 개수': 1812, '가격': 616000, '사이트': '부킹 닷컴'},
#  {'이름': '파라다이스 호텔 부산', '평점': 4.4, '리뷰 개수': 1082, '가격': 532400, '사이트': '부킹 닷컴'},
#  {'이름': '파크하얏트 부산', '평점': 4.4, '리뷰 개수': 797, '가격': 385000, '사이트': '부킹 닷컴'},
#  {'이름': '시그니엘 부산', '평점': 4.1, '리뷰 개수': 36, '가격': 544500, '사이트': '부킹 닷컴'},
#  {'이름': '펠릭스 바이 STX 호텔 & 스위트',
#   '평점': 4.3,
#   '리뷰 개수': 1659,
#   '가격': 88000,
#   '사이트': '부킹 닷컴'},
#  {'이름': '신라스테이 해운대', '평점': 4.05, '리뷰 개수': 1443, '가격': 220000, '사이트': '부킹 닷컴'},
#  {'이름': '베스트웨스턴 해운대 호텔',
#   '평점': 4.05,
#   '리뷰 개수': 1971,
#   '가격': 77000,
#   '사이트': '부킹 닷컴'},
#  {'이름': '페어필드 바이 메리어트 부산',
#   '평점': 4.1,
#   '리뷰 개수': 226,
#   '가격': 94446,
#   '사이트': '부킹 닷컴'},
#  {'이름': '롯데 호텔 부산', '평점': 4.35, '리뷰 개수': 1146, '가격': 193601, '사이트': '부킹 닷컴'},
#  {'이름': '토요코인 부산 해운대 2',
#   '평점': 4.2,
#   '리뷰 개수': 1421,
#   '가격': 49500,
#   '사이트': '부킹 닷컴'},
#  {'이름': '해운대 마리안느 호텔', '평점': 3.8, '리뷰 개수': 995, '가격': 62000, '사이트': '부킹 닷컴'},
#  {'이름': '라마다 앙코르 바이 윈덤 부산 해운대',
#   '평점': 4.25,
#   '리뷰 개수': 1099,
#   '가격': 106764,
#   '사이트': '부킹 닷컴'},
#  {'이름': '켄트 호텔 광안리 by 켄싱턴',
#   '평점': 4.05,
#   '리뷰 개수': 658,
#   '가격': 212400,
#   '사이트': '부킹 닷컴'},
#  {'이름': '부산 웨스틴조선호텔', '평점': 4.25, '리뷰 개수': 459, '가격': 385000, '사이트': '부킹 닷컴'},
#  {'이름': '센텀 프리미어 호텔', '평점': 4.1, '리뷰 개수': 1319, '가격': 66000, '사이트': '부킹 닷컴'},
#  {'이름': '해운대 센텀 호텔', '평점': 4.1, '리뷰 개수': 1487, '가격': 110000, '사이트': '부킹 닷컴'},
#  {'이름': '이비스 앰배서더 부산 해운대',
#   '평점': 3.9,
#   '리뷰 개수': 630,
#   '가격': 67760,
#   '사이트': '부킹 닷컴'},
#  {'이름': '라발스호텔', '평점': 4.15, '리뷰 개수': 585, '가격': 146700, '사이트': '부킹 닷컴'},
#  {'이름': '농심 호텔', '평점': 4.15, '리뷰 개수': 545, '가격': 99000, '사이트': '부킹 닷컴'},
#  {'이름': 'MS 호텔 해운대', '평점': 4.3, '리뷰 개수': 1115, '가격': 137000, '사이트': '부킹 닷컴'},
#  {'이름': '그랜드 엘시티 레지던스', '평점': 4.2, '리뷰 개수': 23, '가격': 770000, '사이트': '부킹 닷컴'},
#  {'이름': '호텔 아벤트리 부산', '평점': 4.35, '리뷰 개수': 1117, '가격': 66000, '사이트': '부킹 닷컴'},
#  {'이름': '토요코인 부산역1호점', '평점': 4.15, '리뷰 개수': 1413, '가격': 57200, '사이트': '부킹 닷컴'},
#  {'이름': '글로리 콘도 해운대', '평점': 3.5, '리뷰 개수': 566, '가격': 77400, '사이트': '부킹 닷컴'}]
